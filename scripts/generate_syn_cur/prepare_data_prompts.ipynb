# %%
import pandas as pd
import random
from datasets import Dataset

data_folder    = './data'
train_folder   = f'{data_folder}/train'

sorted_dict_path = './feature_order_permutation.txt'
# PAFT orders for datasets
with open(sorted_dict_path, 'r') as f:
    sorted_order_dict = eval(f.read())

# Info about datasets
data_info_path = './data_info.csv'
data_info = pd.read_csv(data_info_path, index_col='df_name').sort_values('row_number')

data_info

# %% [markdown]
# # Datasets for standard training

# %%
PAFT_ORDER = True

output_folder = f"./data/datasets_for_standard_FT/{'PAFT' if PAFT_ORDER else 'GREAT'}"

for df_name in data_info.index:
    df_train = pd.read_csv(f'{train_folder}/{df_name}.csv')
    
    if PAFT_ORDER:
        order = sorted_order_dict[df_name]

        if order == '':
            # No df in calculated func dependencies
            order = df_train.columns.tolist() # a fixed random order for all samples
            # random order
            random.shuffle(order)
            order = ','.join(order)

    else:
        order = df_train.columns.tolist()
        order = ','.join(order)

    df_train = df_train[order.split(',')] * 1

    df_text = []
    for i in range(len(df_train)):
        row = df_train.loc[i]
        cols, vals = row.index, row.values

        text = ', '.join([f'{col} is {int(val) if val.is_integer() else round(val, 3)}' for col, val in zip(cols, vals)])
        df_text.append(text)


    df_for_tuning_pandas = pd.DataFrame({'output' : df_text})
    df_for_tuning_pandas['instruction'] = 'Generate a synthetic sample giving an order of the columns. There must be no columns that were not provided in order!'
    df_for_tuning_pandas['input'] = order

    dataset_DS = Dataset.from_pandas(df_for_tuning_pandas)

    dataset_DS.save_to_disk(f'{output_folder}/{df_name}_prompts_train')

# %% [markdown]
# # Datasets for batch training

# %%
PAFT_ORDER = True
output_folder = f"./data/datasets_for_batch_FT/{'PAFT' if PAFT_ORDER else 'GREAT'}"
    
N_batch = 10

for df_name in data_info.index:
    df_train = pd.read_csv(f'{train_folder}/{df_name}.csv')
    old_shape = df_train.shape

    df_train = df_train.head(len(df_train) - len(df_train) % N_batch)

    if PAFT_ORDER:
        order = sorted_order_dict[df_name]

        if order == '':
            # No df in calculated func dependencies
            order = df_train.columns.tolist() # a fixed random order for all samples
            # random order
            random.shuffle(order)
            order = ','.join(order)

    else:
        order = df_train.columns.tolist()
        order = ','.join(order)

    df_train = df_train[order.split(',')] * 1

    df_text = []
    for i in range(len(df_train)):
        row = df_train.loc[i]
        cols, vals = row.index, row.values

        text = ', '.join([f'{col} is {int(val) if val.is_integer() else round(val, 3)}' for col, val in zip(cols, vals)])
        df_text.append(text)

    df_text_Nbatch = []
    number_of_iters = len(df_text) // N_batch

    for i in range(number_of_iters):
        df_text_slice = df_text[i*N_batch:(i+1)*N_batch]
        N_samples_line = ''
        for sample_idx, sample in enumerate(df_text_slice):
            N_samples_line += f'Sample {sample_idx}: {sample}\n'
        
        df_text_Nbatch.append(N_samples_line)
        
    df_for_tuning_pandas = pd.DataFrame({'output' : df_text_Nbatch})
    df_for_tuning_pandas['instruction'] = f'Generate {N_batch} synthetic samples giving an order of the columns. There must be no columns that were not provided in order!'
    df_for_tuning_pandas['input'] = order

    dataset_DS = Dataset.from_pandas(df_for_tuning_pandas)

    dataset_DS.save_to_disk(f'{output_folder}/{df_name}_prompts_train')

# %% [markdown]
# # Datasets for batch anon training

# %%
PAFT_ORDER = True

N_batch = 10

output_folder = f"./data/datasets_for_batch_anon_FT/{'PAFT' if PAFT_ORDER else 'GREAT'}"

for df_name in data_info.index:
    df_train = pd.read_csv(f'{train_folder}/{df_name}.csv')
    old_shape = df_train.shape

    df_train = df_train.head(len(df_train) - len(df_train) % N_batch)
    print(df_name, ", old shape:", old_shape, 'new shape:', df_train.shape)

    if PAFT_ORDER:
        order = sorted_order_dict[df_name]

        if order == '':
            # No df in calculated func dependencies
            order = df_train.columns.tolist() # a fixed random order for all samples
            # random order
            random.shuffle(order)
            order = ','.join(order)

    else:
        order = df_train.columns.tolist()
        order = ','.join(order)

    df_train = df_train[order.split(',')] * 1

    print(df_name, ":", order)

    df_text = []
    cols = [f'col{i}' for i in range(1, len(df_train.columns) + 1)]

    for i in range(len(df_train)):
        row = df_train.loc[i]
        vals = row.values

        text = ', '.join([f'{col} is {int(val) if val.is_integer() else round(val, 3)}' for col, val in zip(cols, vals)])
        df_text.append(text)

    df_text_Nbatch = []
    number_of_iters = len(df_text) // N_batch

    for i in range(number_of_iters):
        df_text_slice = df_text[i*N_batch:(i+1)*N_batch]
        N_samples_line = ''
        for sample_idx, sample in enumerate(df_text_slice):
            N_samples_line += f'Sample {sample_idx}: {sample}\n'
        
        df_text_Nbatch.append(N_samples_line)
        
    df_for_tuning_pandas = pd.DataFrame({'output' : df_text_Nbatch})
    df_for_tuning_pandas['instruction'] = f'Generate {N_batch} synthetic samples giving an order of the columns. There must be no columns that were not provided in order!'
    df_for_tuning_pandas['input'] = ','.join(cols)

    dataset_DS = Dataset.from_pandas(df_for_tuning_pandas)

    dataset_DS.save_to_disk(f'{output_folder}/{df_name}_prompts_train')

# %% [markdown]
# # Dataset augmented by synthetic data

# %%
from sklearn.model_selection import train_test_split

real_data_folder    = './data'
real_train_folder = f'{real_data_folder}/train'

# %%
PAFT_ORDER = True
N_batch = 10

for curated in [True, False]:
    if curated:
        synt_train_folder = './curated_syn_data/batch_training'
    else:
        synt_train_folder = './syn_data/batch_training'
        
    #  First number is % of syn, second is % of real
    for syn_2_real_prc in [(70, 30), (50, 50), (30, 70)]:
        syn_prc, real_prc = syn_2_real_prc

        output_folder = f"./datasets_for_FT_{syn_prc}_{real_prc}_batch{'_curated' if curated else ''}/{'PAFT' if PAFT_ORDER else 'GREAT'}"

        for df_name in data_info.index:
            real_train = pd.read_csv(f'{real_train_folder}/{df_name}.csv')
            
            syn_train = pd.concat(
                [
                    pd.read_csv(f'{synt_train_folder}/{df_name}/X_syn_{i}.csv') 
                    for i in range(len(os.listdir(f'{synt_train_folder}/{df_name}')))
                    ]
                )

            train_size = real_train.shape[0]

            target_name = data_info.loc[df_name, 'target_name']
            if data_info.loc[df_name, 'task_type'] == 'regression':
                real_stratify_arg = None
                syn_stratify_arg  = None
            else:
                real_stratify_arg = real_train[target_name]
                syn_stratify_arg  = syn_train[target_name]

            sampled_real_train, _ = train_test_split(
                                        real_train, 
                                        train_size=(real_prc / 100), 
                                        random_state=42,
                                        stratify=real_stratify_arg)
        
            _, sampled_syn_train = train_test_split(
                                        syn_train, 
                                        test_size=(train_size - sampled_real_train.shape[0]), 
                                        random_state=42,
                                        stratify=syn_stratify_arg)
            
            df_train = pd.concat([sampled_real_train, sampled_syn_train]).sample(frac=1).reset_index(drop=True)
        
            old_shape = df_train.shape
            df_train = df_train.head(len(df_train) - len(df_train) % N_batch)
        

            if PAFT_ORDER:
                order = sorted_order_dict[df_name]

                if order == '':
                    # No df in calculated func dependencies
                    order = df_train.columns.tolist() # a fixed random order for all samples
                    # random order
                    random.shuffle(order)
                    order = ','.join(order)

            else:
                order = df_train.columns.tolist()
                order = ','.join(order)

            df_train = df_train[order.split(',')] * 1

            df_text = []
            for i in range(len(df_train)):
                row = df_train.loc[i]
                cols, vals = row.index, row.values

                text = ', '.join([f'{col} is {int(val) if val.is_integer() else round(val, 3)}' for col, val in zip(cols, vals)])
                df_text.append(text)

            df_text_Nbatch = []
            number_of_iters = len(df_text) // N_batch

            for i in range(number_of_iters):
                df_text_slice = df_text[i*N_batch:(i+1)*N_batch]
                N_samples_line = ''
                for sample_idx, sample in enumerate(df_text_slice):
                    N_samples_line += f'Sample {sample_idx}: {sample}\n'
                
                df_text_Nbatch.append(N_samples_line)
                
            df_for_tuning_pandas = pd.DataFrame({'output' : df_text_Nbatch})
            df_for_tuning_pandas['instruction'] = f'Generate {N_batch} synthetic samples giving an order of the columns. There must be no columns that were not provided in order!'
            df_for_tuning_pandas['input'] = order

            dataset_DS = Dataset.from_pandas(df_for_tuning_pandas)

            dataset_DS.save_to_disk(f'{output_folder}/{df_name}_prompts_train')
